# %%
# dataset
p1 = [127,933]
p2 = [138,741]
p3 = [846,391]
p4 = [876,879]
p5 = [980,580]
p6 = [369,725]
import numpy as np
X = np.array([p1,p2,p3,p4,p5,p6])
# visualization 
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1], c='k')
plt.show()

# %%
from sklearn import cluster
model = cluster.KMeans(n_clusters=2, n_init ='auto')
model.fit(X)
centroids = model.cluster_centers_
labels = model.predict(X)
print(centroids)
print(labels)
# evalutation
from sklearn import metrics
print(metrics.silhouette_score(X, labels))
# Out:
# [[900.66666667 616.66666667]
#  [211.33333333 799.66666667]]
# [1 1 0 0 0 1]
# 0.5917290941075608

# %%
# visualization of dataset
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1], c=labels)
plt.plot(centroids[:,0],centroids[:,1], 'rs')
plt.show()
